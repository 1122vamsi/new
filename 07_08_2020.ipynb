# %% [markdown]
# <a href="https://colab.research.google.com/github/1122vamsi/new/blob/master/07_08_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 204.7MB 66kB/s
# ...
#      |████████████████████████████████| 204kB 43.0MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.0.0-py2.py3-none-any.whl size=205044182 sha256=5ce3a8b1dea5f1c7348f71e4d251e22f48ad27361a68470a5e20f38a368727bc
#   Stored in directory: /root/.cache/pip/wheels/57/27/4d/ddacf7143f8d5b76c45c61ee2e43d9f8492fc5a8e78ebd7d37
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("sample") \
    .getOrCreate()

# %%
from pyspark import SparkContext
sc = SparkContext("local", "sample").getOrCreate()

# %%
spark.stop()

# %%
from pyspark.ml.image import ImageSchema

# %%
images = sc.binaryFiles("/content/drive/My Drive/IMG-20180913-WA0014.jpg")

# %%
type(images)
# Out:
# pyspark.rdd.RDD

# %%
df = spark.createDataFrame(images)

# %%
df.show(5, truncate=False)
# Out:
# +----------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
images.saveAsSequenceFile("/content/drive/My Drive/test_seq")

# %%
new = sc.sequenceFile("/content/drive/My Drive/test_seq")

# %%
a = new.collect()

# %%
type(a[0][1])
# Out:
# bytearray

# %%
from PIL import Image

# %%
def img_show(binary_content):
  cmap = {'0': (255,255,255),
        '1': (0,0,0)}

  data = [cmap[letter] for letter in binary_content]
  img = Image.new('RGB', (8, len(value)//8), "white")
  img.putdata(data)
  img.show() 
  return 0

# %%
import cv2
import numpy as np
decoded = cv2.imdecode(np.frombuffer(a[0][1], np.uint8), -1)

# %%
img = Image.fromarray(decoded, 'RGB')

# %%
from IPython.display import Image, display

# %%
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x960 at 0x7F35E7105A20>
